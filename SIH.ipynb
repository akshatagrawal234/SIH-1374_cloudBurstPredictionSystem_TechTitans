# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cloudburst.csv')

# %%
df.head(15)
# Out:
#           Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1   02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2   03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3   04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4   05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
# 5   06-12-2008   Albury     14.6     29.7       0.2          NaN       NaN
# 6   07-12-2008   Albury     14.3     25.0       0.0          NaN       NaN
# 7   08-12-2008   Albury      7.7     26.7       0.0          NaN       NaN
# 8   09-12-2008   Albury      9.7     31.9       0.0          NaN       NaN
# 9   10-12-2008   Albury     13.1     30.1       1.4          NaN       NaN
# 10  11-12-2008   Albury     13.4     30.4       0.0          NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                145460 non-null  object
#  1   Location            145460 non-null  object
#  2   MinTemp             143975 non-null  float64
#  3   MaxTemp             144199 non-null  float64
#  4   Rainfall            142199 non-null  float64
#  5   Evaporation         82670 non-null   float64
#  6   Sunshine            75625 non-null   float64
#  7   WindGustDir         135134 non-null  object
#  8   WindGustSpeed       135197 non-null  float64
#  9   WindDir9am          134894 non-null  object
#  10  WindDir3pm          141232 non-null  object
#  11  WindSpeed9am        143693 non-null  float64
#  12  WindSpeed3pm        142398 non-null  float64
#  13  Humidity9am         142806 non-null  float64
#  14  Humidity3pm         140953 non-null  float64
# ...

# %%
df1 = pd.DataFrame(df)
unique_categories = df['WindGustDir'].unique()
print(unique_categories)
# Out:
# ['W' 'WNW' 'WSW' 'NE' 'NNW' 'N' 'NNE' 'SW' nan 'ENE' 'SSE' 'S' 'NW' 'SE'
#  'ESE' 'E' 'SSW']

# %%
unique_categories1 = df['CloudBurst Today'].unique()
print(unique_categories1)
# Out:
# ['No' 'Yes' nan]

# %%
unique_categories1 = df['CloudBurstTomorrow'].unique()
print(unique_categories1)
# Out:
# ['No' 'Yes' nan]

# %%
unique_categories1 = df['Location'].unique()
print(unique_categories1)
# Out:
# ['Albury' 'BadgerysCreek' 'Cobar' 'CoffsHarbour' 'Moree' 'Newcastle'
#  'NorahHead' 'NorfolkIsland' 'Penrith' 'Richmond' 'Sydney' 'SydneyAirport'
#  'WaggaWagga' 'Williamtown' 'Wollongong' 'Canberra' 'Tuggeranong'
#  'MountGinini' 'Ballarat' 'Bendigo' 'Sale' 'MelbourneAirport' 'Melbourne'
#  'Mildura' 'Nhil' 'Portland' 'Watsonia' 'Dartmoor' 'Brisbane' 'Cairns'
#  'GoldCoast' 'Townsville' 'Adelaide' 'MountGambier' 'Nuriootpa' 'Woomera'
#  'Albany' 'Witchcliffe' 'PearceRAAF' 'PerthAirport' 'Perth' 'SalmonGums'
#  'Walpole' 'Hobart' 'Launceston' 'AliceSprings' 'Darwin' 'Katherine'
#  'Uluru']

# %%
# Convert the "Date" column to datetime format
df['Date'] = pd.to_datetime(df['Date'])
df["month"] = df["Date"].dt.month
df["Date_day"] = df["Date"].dt.day
# Out:
# C:\Users\MOHIT KUMAR\AppData\Local\Temp\ipykernel_28780\3310848165.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2008-01-12   Albury     13.4     22.9       0.6          NaN       NaN
# 1      2008-02-12   Albury      7.4     25.1       0.0          NaN       NaN
# 2      2008-03-12   Albury     12.9     25.7       0.0          NaN       NaN
# 3      2008-04-12   Albury      9.2     28.0       0.0          NaN       NaN
# 4      2008-05-12   Albury     17.5     32.3       1.0          NaN       NaN
# ...           ...      ...      ...      ...       ...          ...       ...
# 145455 2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 145456 2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 145457 2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 145458 2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 145459 2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
mean_MinTemp = df['MinTemp'].mean()
mean_MaxTemp = df['MaxTemp'].mean()
mean_Rainfall = df['Rainfall'].mean()

# %%
df['MinTemp'].fillna(mean_MinTemp,inplace = True)
df['MaxTemp'].fillna(mean_MaxTemp,inplace = True)
df['Rainfall'].fillna(mean_Rainfall,inplace = True)

# %%
mean_WindGustSpeed = df['WindGustSpeed'].mean()
mean_WindSpeed9am = df['WindSpeed9am'].mean()
mean_WindSpeed3pm = df['WindSpeed3pm'].mean()
mean_Humidity9am = df['Humidity9am'].mean()
mean_Humidity3pm = df['Humidity3pm'].mean()
mean_Pressure9am = df['Pressure9am'].mean()
mean_Pressure3pm = df['Pressure3pm'].mean()
mean_Temp9am = df['Temp9am'].mean()
mean_Temp3pm = df['Temp3pm'].mean()

# %%
df['WindGustSpeed'].fillna(mean_WindGustSpeed,inplace = True)
df['WindSpeed9am'].fillna(mean_WindSpeed9am,inplace = True)
df['WindSpeed3pm'].fillna(mean_WindSpeed3pm,inplace = True)
df['Humidity9am'].fillna(mean_Humidity9am,inplace = True)
df['Humidity3pm'].fillna(mean_Humidity3pm,inplace = True)
df['Pressure9am'].fillna(mean_Pressure9am,inplace = True)
df['Pressure3pm'].fillna(mean_Pressure3pm,inplace = True)
df['Temp9am'].fillna(mean_Temp9am,inplace = True)
df['Temp3pm'].fillna(mean_Temp3pm,inplace = True)

# %%
df.head(5)
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-01-12   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-02-12   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-03-12   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-04-12   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-05-12   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Pressure9am  Pressure3pm  \
# 0           W           44.0          W  ...      1007.7       1007.1
# 1         WNW           44.0        NNW  ...      1010.6       1007.8
# 2         WSW           46.0          W  ...      1007.6       1008.7
# 3          NE           24.0         SE  ...      1017.6       1012.8
# 4           W           41.0        ENE  ...      1010.8       1006.0
#
#    Cloud9am  Cloud3pm  Temp9am  Temp3pm  CloudBurst Today  CloudBurstTomorrow  \
# ...

# %%
CloudBurstToday_mapping = {'No':0,'Yes':1}
CloudBurstTomorrow_mapping = {'No':0,'Yes':1}
df['CloudBurst Today'] = df['CloudBurst Today'].map(CloudBurstToday_mapping)
df['CloudBurstTomorrow'] = df['CloudBurstTomorrow'].map(CloudBurstTomorrow_mapping)

# %%
df.head(50)
# Out:
#          Date Location  MinTemp  MaxTemp   Rainfall  Evaporation  Sunshine  \
# 0  2008-01-12   Albury     13.4     22.9   0.600000          NaN       NaN
# 1  2008-02-12   Albury      7.4     25.1   0.000000          NaN       NaN
# 2  2008-03-12   Albury     12.9     25.7   0.000000          NaN       NaN
# 3  2008-04-12   Albury      9.2     28.0   0.000000          NaN       NaN
# 4  2008-05-12   Albury     17.5     32.3   1.000000          NaN       NaN
# 5  2008-06-12   Albury     14.6     29.7   0.200000          NaN       NaN
# 6  2008-07-12   Albury     14.3     25.0   0.000000          NaN       NaN
# 7  2008-08-12   Albury      7.7     26.7   0.000000          NaN       NaN
# 8  2008-09-12   Albury      9.7     31.9   0.000000          NaN       NaN
# 9  2008-10-12   Albury     13.1     30.1   1.400000          NaN       NaN
# 10 2008-11-12   Albury     13.4     30.4   0.000000          NaN       NaN
# ...

# %%
CloudBurstToday_mode = df['CloudBurst Today'].mode().values[0]
CloudBurstTomorrow_mode = df['CloudBurstTomorrow'].mode().values[0]
df['CloudBurst Today'].fillna(CloudBurstToday_mode,inplace =True)
df['CloudBurstTomorrow'].fillna(CloudBurstTomorrow_mode,inplace = True)

# %%
df.head(5)
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-01-12   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-02-12   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-03-12   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-04-12   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-05-12   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Pressure9am  Pressure3pm  \
# 0           W           44.0          W  ...      1007.7       1007.1
# 1         WNW           44.0        NNW  ...      1010.6       1007.8
# 2         WSW           46.0          W  ...      1007.6       1008.7
# 3          NE           24.0         SE  ...      1017.6       1012.8
# 4           W           41.0        ENE  ...      1010.8       1006.0
#
#    Cloud9am  Cloud3pm  Temp9am  Temp3pm  CloudBurst Today  CloudBurstTomorrow  \
# ...

# %%
from sklearn.impute import KNNImputer
import pandas as pd
df = pd.DataFrame(df)
col1 = 'Evaporation'
imputer = KNNImputer(n_neighbors = 10)
df['Evaporation'] = imputer.fit_transform(df[[col1]])

# %%
df.head(5)
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-01-12   Albury     13.4     22.9       0.6     5.468232       NaN
# 1 2008-02-12   Albury      7.4     25.1       0.0     5.468232       NaN
# 2 2008-03-12   Albury     12.9     25.7       0.0     5.468232       NaN
# 3 2008-04-12   Albury      9.2     28.0       0.0     5.468232       NaN
# 4 2008-05-12   Albury     17.5     32.3       1.0     5.468232       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Pressure9am  Pressure3pm  \
# 0           W           44.0          W  ...      1007.7       1007.1
# 1         WNW           44.0        NNW  ...      1010.6       1007.8
# 2         WSW           46.0          W  ...      1007.6       1008.7
# 3          NE           24.0         SE  ...      1017.6       1012.8
# 4           W           41.0        ENE  ...      1010.8       1006.0
#
#    Cloud9am  Cloud3pm  Temp9am  Temp3pm  CloudBurst Today  CloudBurstTomorrow  \
# ...

# %%
col2 = 'Sunshine'
imputer = KNNImputer(n_neighbors =5 )
df['Sunshine'] = imputer.fit_transform(df[[col2]])

# %%
col3 = 'Cloud9am'
imputer = KNNImputer(n_neighbors = 5)
df['Cloud9am'] = imputer.fit_transform(df[[col3]])

# %%
col4 = 'Cloud3pm'
imputer = KNNImputer(n_neighbors =5 )
df['Cloud3pm'] = imputer.fit_transform(df[[col4]])

# %%
df.head(5)
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-01-12   Albury     13.4     22.9       0.6     5.468232  7.611178
# 1 2008-02-12   Albury      7.4     25.1       0.0     5.468232  7.611178
# 2 2008-03-12   Albury     12.9     25.7       0.0     5.468232  7.611178
# 3 2008-04-12   Albury      9.2     28.0       0.0     5.468232  7.611178
# 4 2008-05-12   Albury     17.5     32.3       1.0     5.468232  7.611178
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Pressure9am  Pressure3pm  \
# 0           W           44.0          W  ...      1007.7       1007.1
# 1         WNW           44.0        NNW  ...      1010.6       1007.8
# 2         WSW           46.0          W  ...      1007.6       1008.7
# 3          NE           24.0         SE  ...      1017.6       1012.8
# 4           W           41.0        ENE  ...      1010.8       1006.0
#
#    Cloud9am  Cloud3pm  Temp9am  Temp3pm  CloudBurst Today  CloudBurstTomorrow  \
# ...

# %%
df1 = df.copy()

# %%
df1['WindDir9am'].unique()
# Out:
# array(['W', 'NNW', 'SE', 'ENE', 'SW', 'SSE', 'S', 'NE', nan, 'SSW', 'N',
#        'WSW', 'ESE', 'E', 'NW', 'WNW', 'NNE'], dtype=object)

# %%
WindDir3pm_mapping = {'W':1,'NNW':2,'SE':3,'ENE':4,'SW':5,'SSE':6,'S':7,'NE':8,'SSW':9,'N':10,'WSW':11,'ESE':12,'E':13,'NW':14,'WNW':15,'NNE':16}
df1['WindDir3pm'] = df1['WindDir3pm'].map(WindDir3pm_mapping)

# %%
WindGustDir_mapping = {'W':1,'NNW':2,'SE':3,'ENE':4,'SW':5,'SSE':6,'S':7,'NE':8,'SSW':9,'N':10,'WSW':11,'ESE':12,'E':13,'NW':14,'WNW':15,'NNE':16}
df1['WindGustDir'] = df1['WindGustDir'].map(WindGustDir_mapping)

# %%
WindDir9am_mapping = {'W':1,'NNW':2,'SE':3,'ENE':4,'SW':5,'SSE':6,'S':7,'NE':8,'SSW':9,'N':10,'WSW':11,'ESE':12,'E':13,'NW':14,'WNW':15,'NNE':16}
df1['WindDir9am'] = df1['WindDir9am'].map(WindDir9am_mapping)

# %%
df1
# Out:
#              Date Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0      2008-01-12   Albury     13.4  22.900000       0.6     5.468232
# 1      2008-02-12   Albury      7.4  25.100000       0.0     5.468232
# 2      2008-03-12   Albury     12.9  25.700000       0.0     5.468232
# 3      2008-04-12   Albury      9.2  28.000000       0.0     5.468232
# 4      2008-05-12   Albury     17.5  32.300000       1.0     5.468232
# ...           ...      ...      ...        ...       ...          ...
# 145455 2017-06-21    Uluru      2.8  23.400000       0.0     5.468232
# 145456 2017-06-22    Uluru      3.6  25.300000       0.0     5.468232
# 145457 2017-06-23    Uluru      5.4  26.900000       0.0     5.468232
# 145458 2017-06-24    Uluru      7.8  27.000000       0.0     5.468232
# 145459 2017-06-25    Uluru     14.9  23.221348       0.0     5.468232
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Pressure9am  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score

from sklearn.preprocessing import PowerTransformer
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2,random_state=0)

# %%
df1.isnull().sum()*100/len(df1)
# Out:
# Date                  0.0
# Location              0.0
# MinTemp               0.0
# MaxTemp               0.0
# Rainfall              0.0
# Evaporation           0.0
# Sunshine              0.0
# WindGustDir           0.0
# WindGustSpeed         0.0
# WindDir9am            0.0
# WindDir3pm            0.0
# WindSpeed9am          0.0
# WindSpeed3pm          0.0
# Humidity9am           0.0
# Humidity3pm           0.0
# Pressure9am           0.0
# Pressure3pm           0.0
# Cloud9am              0.0
# Cloud3pm              0.0
# Temp9am               0.0
# Temp3pm               0.0
# CloudBurst Today      0.0
# CloudBurstTomorrow    0.0
# month                 0.0
# Date_day              0.0
# dtype: float64

# %%
df1["WindGustDir"] = df1["WindGustDir"].fillna(df1["WindGustDir"].value_counts().index[0])
df1["WindDir9am"] = df1["WindDir9am"].fillna(df1["WindDir9am"].value_counts().index[0])
df1["WindDir3pm"] = df1["WindDir3pm"].fillna(df1["WindDir3pm"].value_counts().index[0])

# %%
df1.isnull().sum()*100/len(df1)
# Out:
# Date                  0.0
# Location              0.0
# MinTemp               0.0
# MaxTemp               0.0
# Rainfall              0.0
# Evaporation           0.0
# Sunshine              0.0
# WindGustDir           0.0
# WindGustSpeed         0.0
# WindDir9am            0.0
# WindDir3pm            0.0
# WindSpeed9am          0.0
# WindSpeed3pm          0.0
# Humidity9am           0.0
# Humidity3pm           0.0
# Pressure9am           0.0
# Pressure3pm           0.0
# Cloud9am              0.0
# Cloud3pm              0.0
# Temp9am               0.0
# Temp3pm               0.0
# CloudBurst Today      0.0
# CloudBurstTomorrow    0.0
# month                 0.0
# Date_day              0.0
# dtype: float64

# %%
x1 = df1.drop(columns = ['CloudBurstTomorrow','Location','Date',])
y1 = df1.iloc[:,-3]

# %%
lr = LogisticRegression()
#Applying Regression without any transformation
lr.fit(x1_train,y1_train)

y_pred=lr.predict(x1_test)

accuracy = accuracy_score(y1_test,y_pred)
# Out:
# C:\Users\MOHIT KUMAR\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy
# Out:
# 0.8389591640313488

# %%
x1
# Out:
#         MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0          13.4  22.900000       0.6     5.468232  7.611178          1.0
# 1           7.4  25.100000       0.0     5.468232  7.611178         15.0
# 2          12.9  25.700000       0.0     5.468232  7.611178         11.0
# 3           9.2  28.000000       0.0     5.468232  7.611178          8.0
# 4          17.5  32.300000       1.0     5.468232  7.611178          1.0
# ...         ...        ...       ...          ...       ...          ...
# 145455      2.8  23.400000       0.0     5.468232  7.611178         13.0
# 145456      3.6  25.300000       0.0     5.468232  7.611178          2.0
# 145457      5.4  26.900000       0.0     5.468232  7.611178         10.0
# 145458      7.8  27.000000       0.0     5.468232  7.611178          3.0
# 145459     14.9  23.221348       0.0     5.468232  7.611178          1.0
#
#         WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
sns.countplot(x='CloudBurstTomorrow', data=df1)

# Optionally, you can set labels for the axes
plt.xlabel('CloudBurstTomorrow')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
for feature in continuous_data:
    sns.distplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[376], line 2
#       1 for feature in continuous_data:
# ----> 2     sns.distplot(data[feature])
#       3     plt.title(feature)
#       4     plt.figure(figsize=(15,15))
#
# NameError: name 'data' is not defined

# %%
sns.boxplot(df1['MinTemp'])
plt.title(MinTemp)
plt.figure(figsize=(15, 15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[377], line 2
#       1 sns.boxplot(df1['MinTemp'])
# ----> 2 plt.title(MinTemp)
#       3 plt.figure(figsize=(15, 15))
#
# NameError: name 'MinTemp' is not defined

# %%
sns.boxplot(df1['MaxTemp'])
plt.title(MaxTemp)
plt.figure(figsize=(15, 15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[378], line 2
#       1 sns.boxplot(df1['MaxTemp'])
# ----> 2 plt.title(MaxTemp)
#       3 plt.figure(figsize=(15, 15))
#
# NameError: name 'MaxTemp' is not defined

# %%
#for minimum temperature
IQR=df1.MinTemp.quantile(0.75)-df1.MinTemp.quantile(0.25)
lower_limit=df1.MinTemp.quantile(0.25)-(IQR*1.5)
upper_limit=df1.MinTemp.quantile(0.75)+(IQR*1.5)
print(lower_limit, upper_limit)
# Out:
# -5.950000000000002 30.450000000000003

# %%
df1.loc[df1['MinTemp']>=30.45,'MinTemp']=30.45
df1.loc[df1['MinTemp']<=-5.95,'MinTemp']=-5.95

# %%
IQR=df1.MaxTemp.quantile(0.75)-df1.MaxTemp.quantile(0.25)
lower_limit=df1.MaxTemp.quantile(0.25)-(IQR*1.5)
upper_limit=df1.MaxTemp.quantile(0.75)+(IQR*1.5)
print(lower_limit, upper_limit)
# Out:
# 2.700000000000001 43.5

# %%
df1.loc[df1['MaxTemp']>=43.5,'MaxTemp']=43.5
df1.loc[df1['MaxTemp']<=2.7,'MaxTemp']=2.7

# %%
IQR=df1.Rainfall.quantile(0.75)-df1.Rainfall.quantile(0.25)
lower_limit=df1.Rainfall.quantile(0.25)-(IQR*1.5)
upper_limit=df1.Rainfall.quantile(0.75)+(IQR*1.5)
print(lower_limit, upper_limit)
# Out:
# -1.5 2.5

# %%
df1.loc[df1['Rainfall']>=2.5,'Rainfall']=2.5
df1.loc[df1['Rainfall']<=-1.5,'Rainfall']=-1.5

# %%
IQR=df1.Evaporation.quantile(0.75)-df1.Evaporation.quantile(0.25)
lower_limit=df1.Evaporation.quantile(0.25)-(IQR*1.5)
upper_limit=df1.Evaporation.quantile(0.75)+(IQR*1.5)
print(lower_limit, upper_limit)
# Out:
# 1.797652715616307 7.670578807306155

# %%
df1.loc[df1['Evaporation']>=7.67,'Evaporation']=7.67
df1.loc[df1['Evaporation']<=1.79,'Evaporation']=1.79

# %%
IQR=df1.Sunshine.quantile(0.75)-df1.Sunshine.quantile(0.25)
lower_limit=df1.Sunshine.quantile(0.25)-(IQR*1.5)
upper_limit=df1.Sunshine.quantile(0.75)+(IQR*1.5)
print(lower_limit, upper_limit)
# Out:
# 5.977943801652892 10.333233719008263

# %%
df1.loc[df1['Sunshine']>=10.33,'Sunshine']=10.33
df1.loc[df1['Sunshine']<=5.97,'Sunshine']=5.97

# %%
IQR=df1.WindGustSpeed.quantile(0.75)-df1.WindGustSpeed.quantile(0.25)
lower_limit=df1.WindGustSpeed.quantile(0.25)-(IQR*1.5)
upper_limit=df1.WindGustSpeed.quantile(0.75)+(IQR*1.5)
print(lower_limit, upper_limit)
# Out:
# 8.5 68.5

# %%
df1.loc[df1['WindGustSpeed']>=68.5,'Sunshine']=68.5
df1.loc[df1['WindGustSpeed']<=8.5,'Sunshine']=8.5

# %%
IQR=df1.WindSpeed9am.quantile(0.75)-df1.WindSpeed9am.quantile(0.25)
lower_limit=df1.WindSpeed9am.quantile(0.25)-(IQR*1.5)
upper_limit=df1.WindSpeed9am.quantile(0.75)+(IQR*1.5)
print(lower_limit, upper_limit)
# Out:
# -11.0 37.0

# %%
df1.loc[df1['WindSpeed9am']>=37.0,'WindSpeed9am']=37.0
df1.loc[df1['WindSpeed9am']<=-11.0,'WindSpeed9am']=-11.0

# %%
IQR=df1.WindSpeed3pm.quantile(0.75)-df1.WindSpeed3pm.quantile(0.25)
lower_limit=df1.WindSpeed3pm.quantile(0.25)-(IQR*1.5)
upper_limit=df1.WindSpeed3pm.quantile(0.75)+(IQR*1.5)
df1.loc[df1['WindSpeed3pm']>=upper_limit,'WindSpeed3pm']=upper_limit
df1.loc[df1['WindSpeed3pm']<=lower_limit,'WindSpeed3pm']=lower_limit

# %%
IQR=df1.Humidity9am.quantile(0.75)-df1.Humidity9am.quantile(0.25)
lower_limit=df1.Humidity9am.quantile(0.25)-(IQR*1.5)
upper_limit=df1.Humidity9am.quantile(0.75)+(IQR*1.5)
df1.loc[df1['Humidity9am']>=upper_limit,'Humidity9am']=upper_limit
df1.loc[df1['Humidity9am']<=lower_limit,'Humidity9am']=lower_limit

# %%
IQR=df1.Pressure9am.quantile(0.75)-df1.Pressure9am.quantile(0.25)
lower_limit=df1.Pressure9am.quantile(0.25)-(IQR*1.5)
upper_limit=df1.Pressure9am.quantile(0.75)+(IQR*1.5)
df1.loc[df1['Pressure9am']>=upper_limit,'Pressure9am']=upper_limit
df1.loc[df1['Pressure9am']<=lower_limit,'Pressure9am']=lower_limit

# %%
IQR=df1.Pressure3pm.quantile(0.75)-df1.Pressure3pm.quantile(0.25)
lower_limit=df1.Pressure3pm.quantile(0.25)-(IQR*1.5)
upper_limit=df1.Pressure3pm.quantile(0.75)+(IQR*1.5)
df1.loc[df1['Pressure3pm']>=upper_limit,'Pressure3pm']=upper_limit
df1.loc[df1['Pressure3pm']<=lower_limit,'Pressure3pm']=lower_limit

# %%
IQR=df1.Temp9am.quantile(0.75)-df1.Temp9am.quantile(0.25)
lower_limit=df1.Temp9am.quantile(0.25)-(IQR*1.5)
upper_limit=df1.Temp9am.quantile(0.75)+(IQR*1.5)
df1.loc[df1['Temp9am']>=upper_limit,'Temp9am']=upper_limit
df1.loc[df1['Temp9am']<=lower_limit,'Temp9am']=lower_limit

# %%
IQR=df1.Temp3pm.quantile(0.75)-df1.Temp3pm.quantile(0.25)
lower_limit=df1.Temp3pm.quantile(0.25)-(IQR*1.5)
upper_limit=df1.Temp3pm.quantile(0.75)+(IQR*1.5)
df1.loc[df1['Temp3pm']>=upper_limit,'Temp3pm']=upper_limit
df1.loc[df1['Temp3pm']<=lower_limit,'Temp3pm']=lower_limit

# %%
df1.shape
# Out:
# (145460, 25)

# %%
x2_train,x2_test,y2_train,y2_test=train_test_split(x2,y2,test_size=0.2,random_state=0)
x2 = df1.drop(columns = ['CloudBurstTomorrow','Location','Date',])
y2 = df1.iloc[:,-3]
lr = LogisticRegression()
#Applying Regression without any transformation
lr.fit(x2_train,y2_train)

y1_pred=lr.predict(x2_test)

accuracy = accuracy_score(y1_test,y1_pred)
# Out:
# C:\Users\MOHIT KUMAR\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy*100
# Out:
# 83.8718548054448
